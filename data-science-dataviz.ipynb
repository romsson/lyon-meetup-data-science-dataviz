# %% [markdown]
# # The (Data) Science of Dataviz
#
#
# ## *Romain Vuillemot*
#
# <img src='http://romain.vuillemot.net/img/romain-vuillemot.png' style='width: 200px; float:left; margin: 20px'>
#
# <br><br><br><br>
# [@romsson](https://twitter.com/romsson)
#
# [http://romain.vuillemot.net/](http://romain.vuillemot.net/)
#
# <br><br>
#
# *Notes for a talk given during the [Lyon Data Science meetup](http://www.meetup.com/Lyon-Data-Science/events/227856813/)*
#
# *Source [https://github.com/romsson/data-science-dataviz](https://github.com/romsson/data-science-dataviz)*

# %% [markdown]
# ## [http://romain.vuillemot.net/](http://romain.vuillemot.net/)
#
# <iframe src='http://romain.vuillemot.net/projects/' width='100%' style='width=600px; height: 500px;'></iframe>
#
# *A full list of my projects and publications is availble at [http://romain.vuillemot.net/](http://romain.vuillemot.net/) with related code source and materials (usually videos and screenshots). And of course interactive prototype you can play with.*

# %% [markdown]
# ## The Globe of Economic Complexity
#
# <div style='text-align: center'>
#   <a href='https://twitter.com/romsson/status/636150555933585408'>
#   <img src='data-science-dataviz/globe-falling-sand-africa.gif' style='height: 500px'></a>
# </div>
#
# *The Globe of Economic Complexity visualizes 15 trillion dollars of world trade. One dot equals 100 million dollars of exported products. It uses Three.js & WebGL. Check it out: [http://globe.cid.harvard.edu/](http://globe.cid.harvard.edu/).*

# %% [markdown]
# ## El Atlas de Complejidad Económica de México<br>*Mexican Atlas of Economic Complexity*
#
# <iframe src='http://complejidad.datos.gob.mx/' width='100%' style='width=600px; height: 500px;'></iframe>
#
# *The Mexican Atlas of Economic Complexity is a diagnostic tool that firms, investors and policymakers can use to improve the productivity of states, cities and municipalities. Check it out: [http://complejidad.datos.gob.mx/](http://complejidad.datos.gob.mx/)*

# %% [markdown]
# By the way you can view, download or [re-compile](http://www.slideviper.oquanta.info/tutorial/slideshow_tutorial_slides.html#/11) this presentation:
#
# ```
# > ipython nbconvert --to slides data-science-dataviz.ipynb --post serve
# ```

# %% [markdown]
# Want to see the source code? Fix a typo? Re-use? [https://github.com/romsson/lyon-meetup-data-science-dataviz/](https://github.com/romsson/lyon-meetup-data-science-dataviz/)

# %% [markdown]
# # What is data visualization?

# %% [markdown]
# ## (pre)-Historical Example
#
# <div style='text-align: center'>
#   <img src='data-science-dataviz/example-pre-historic.jpg' style='width=500px'>
# </div>
#
# [Kish tablet](https://en.wikipedia.org/wiki/Kish_tablet) with proto-cuneiform signs dated to ca. 3500 BC.

# %% [markdown]
# ## William Playfair
#
#
# <img src='https://upload.wikimedia.org/wikipedia/commons/5/52/Playfair_TimeSeries-2.png' style='width: 900px'>
#
# Exports and imports to and form Denmark & Norway from 1700 to 1780

# %% [markdown]
# ## Joseph Minard
#
# <div style='text-align: center'>
#   <img src='data-science-dataviz/minard-russia.png'>
# </div>
#
# Carte figurative des pertes successives en hommes de l'Armée Française dans la campagne de Russie 1812-1813 https://en.wikipedia.org/wiki/Charles_Joseph_Minard

# %% [markdown]
# ## Joseph Minard
#
# <div style='text-align: center'>
#   <img src='https://upload.wikimedia.org/wikipedia/commons/1/1c/Minard-carte-viande-1858.png' style='width: 600px'>
# </div>
#
# Carte figurative et approximative des quantités de viandes de boucherie envoyées sur pied par les départements et consommateurs à Paris. source: https://en.wikipedia.org/wiki/Charles_Joseph_Minard

# %% [markdown]
# ## John Snow
#
# <div style='text-align: center'>
#   <img src='thumbs/snow-cholera-map.jpg' style='width: 600px'>
# </div>
#
# Cholera cases in the London epidemic of 1854 https://en.wikipedia.org/wiki/John_Snow_(physician)

# %% [markdown]
# # E. J. Marey
#
# <div style='text-align: center'>
#   <img src='thumbs/marey-train-schedule.jpg' style='width: 900px'>
# </div>
#
# E. J. Marey's graphical schedule shows actual speed of trains with the slop of the line: the steeper the line, the faster the train.

# %% [markdown]
# ## Jacques Bertin
#
# <iframe width="560" height="315" src="https://www.youtube.com/embed/RZzjuma2F-E?rel=0" frameborder="0" allowfullscreen></iframe>
#
# *[Jacques Bertin](https://en.wikipedia.org/wiki/Jacques_Bertin) (1918 – 2010) was a French cartographer and theorist, known from his book Semiologie Graphique (Semiology of Graphics), published in 1967.*
#
# More details on [data visualization milestones](data visualization that we call "milestones.) and [historical examples](http://www.t-o-m-b-o-l-o.eu/meta/histoire-de-tourner-en-rond-breves-cousues-main-du-fromage-normand-a-barack-obama-2/).

# %% [markdown]
# # Why visualize?

# %% [markdown]
# ## Example #1
#
# Find the minimal value for the following equation:
#
# $1.3 x^2 + 4 x + 0.6$

# %% [markdown]
# Let's just automatically find the minimal value using `scipy`

# %%
import numpy as np
import scipy.optimize as opt

objective = np.poly1d([1.3, 4.0, 0.6])
x_ = opt.fmin(objective, [3])
print("solved: x={}".format(x_))
# Out:
# Optimization terminated successfully.
#          Current function value: -2.476923
#          Iterations: 20
#          Function evaluations: 40
# solved: x=[-1.53845215]

# %%
# %matplotlib inline
import matplotlib.pylab as plt
from ipywidgets import widgets
from IPython.display import display

x = np.linspace(-4, 1, 101.)
fig = plt.figure(figsize=(10, 8))
plt.plot(x, objective(x))
plt.plot(x_, objective(x_), 'ro')
plt.show()

# %% [markdown]
# ## Example #2
#
# Find interesting patterns in those 4 datasets with eleven (x,y) points.
#
#
# | I    |       | II   |      | III  |       | IV   |       |
# |------|-------|------|------|------|-------|------|-------|
# | x    | y     | x    | y    | x    | y     | x    | y     |
# | 10.0 | 8.04  | 10.0 | 9.14 | 10.0 | 7.46  | 8.0  | 6.58  |
# | 8.0  | 6.95  | 8.0  | 8.14 | 8.0  | 6.77  | 8.0  | 5.76  |
# | 13.0 | 7.58  | 13.0 | 8.74 | 13.0 | 12.74 | 8.0  | 7.71  |
# | 9.0  | 8.81  | 9.0  | 8.77 | 9.0  | 7.11  | 8.0  | 8.84  |
# | 11.0 | 8.33  | 11.0 | 9.26 | 11.0 | 7.81  | 8.0  | 8.47  |
# | 14.0 | 9.96  | 14.0 | 8.10 | 14.0 | 8.84  | 8.0  | 7.04  |
# | 6.0  | 7.24  | 6.0  | 6.13 | 6.0  | 6.08  | 8.0  | 5.25  |
# | 4.0  | 4.26  | 4.0  | 3.10 | 4.0  | 5.39  | 19.0 | 12.50 |
# | 12.0 | 10.84 | 12.0 | 9.13 | 12.0 | 8.15  | 8.0  | 5.56  |
# | 7.0  | 4.82  | 7.0  | 7.26 | 7.0  | 6.42  | 8.0  | 7.91  |
# | 5.0  | 5.68  | 5.0  | 4.74 | 5.0  | 5.73  | 8.0  | 6.89  |
#
# The [Anscombe's quartet](https://en.wikipedia.org/wiki/Anscombe%27s_quartet).

# %% [markdown]
# All points nearly have **identical** simple statistical properties:
#
#
# | Property	            | Value                |
# |-----------------------|----------------------|
# | Mean of x             |	9                  |
# | Sample variance of x  |	11                 |
# | Mean of y             |	7.50               |
# | Sample variance of y  |   4.122              |
# | Correlation           |   0.816              |
# | Linear regression line|   y = 3.00 + 0.500x  |

# %% [markdown]
# Not so identical, **visually**.
#
# <div style='text-align: center'>
#   <img src='https://upload.wikimedia.org/wikipedia/commons/thumb/e/ec/Anscombe%27s_quartet_3.svg/990px-Anscombe%27s_quartet_3.svg.png' style='width: 700px'>
# </div>

# %% [markdown]
# # Why is it difficult?

# %% [markdown]
# Take some time finding the best way to visually represent those two quantities:
#
# <br><br><br>
#
# <div style='font-size: 300%; text-align: center;'>75 &nbsp;&nbsp;&nbsp;&nbsp; 37</div>

# %% [markdown]
# <iframe src='http://blog.visual.ly/45-ways-to-communicate-two-quantities/' width='100%' style='width=900px; height: 700px;'></iframe>

# %% [markdown]
# See the full list in [45 Ways to communicate two quantities](http://blog.visual.ly/45-ways-to-communicate-two-quantities/) by Santiago Ortiz

# %% [markdown]
# ## Visualization as.. a combinatorial problem
#
#
# Line, Circle, Rectangle, .. (Graphical Marks)
#
# $\times$ Position, Size, Color, .. (Properties)
#
# $\times$ Selection, Binning, Aggregation, .. (Data transformation)
#
# $=$ Huge number of permutations (even for small and simple datasets)

# %% [markdown]
# ## What to optimize? How to evaluate?
#
# * Some principles allow to reduce the size of the space and directly jump to interesting points
#
# * Otherwise, **no automatic rules** to generate a visualization: each visualization has a specific role, efficiency in a given **context**.

# %% [markdown]
# ## Gestalt / theories of visual perception
#
# Humans visual system has a natural hability to generate similarity, continuation, closure, etc. among visual elements.
#
# <img src='http://www.fusioncharts.com/blog/wp-content/uploads/2014/03/597x323xillustrations.jpg.pagespeed.ic.E4Yr9kUmb6.webp'>

# %% [markdown]
# ## Chart junk
#
# Uncessary (?) use of decorations/ornament that can impair readability (but increase engagement, memorability, branding).
#
# <img src='https://i1.wp.com/eagereyes.org/media/2011/memory-monster.jpg?'>
#
#
# R.Kosara [Want to Make A Chart Memorable? Add Junk](https://eagereyes.org/blog/2011/want-to-make-chart-memorable-add-junk)

# %% [markdown]
# ##  Aesthetic
#
# <img src='data-science-dataviz/storyline-aesthetic.png' width=600>
#
# Andrew Vande Moere, Helen Purchase. [*On the role of design in information
# visualization.*](http://infoscape.org/publications/ivs12.pdf)

# %% [markdown]
# # Graphical Marks & Properties

# %% [markdown]
# ## Marks and properties list
#
# <div style='text-align: center'>
#   <img src='http://www.infovis-wiki.net/images/8/89/VisualVariables.png'>
# </div>
#
# Bertin, Jacques. "Semiology of graphics: diagrams, networks, maps." (1967).

# %% [markdown]
# ## Marks and properties variations
#
#
# <img src='data-science-dataviz/bertin-semiology.jpg' style='width: 500px'>
#
# Bertin, Jacques. "Semiology of graphics: diagrams, networks, maps." (1967).

# %% [markdown]
# ## Ranking of graphical marks
#
# <div style='text-align: center'>
#   <img src='data-science-dataviz/mackinlay-hierarchy.png' style='height: 500px'>
# </div>
#
# *Mackinlay, Jock. ["Automating the design of graphical presentations of relational information."](http://www2.parc.com/istl/groups/uir/publications/items/UIR-1986-02-Mackinlay-TOG-Automating.pdf) Acm Transactions On Graphics (Tog) 5.2 (1986): 110-141.*

# %% [markdown]
# ## Ranking of graphical marks by data type
#
# <div style='text-align: center'>
#   <img src='data-science-dataviz/mackinlay-types.png' style='height: 500px'>
# </div>
#
# *Mackinlay, Jock. ["Automating the design of graphical presentations of relational information."](http://www2.parc.com/istl/groups/uir/publications/items/UIR-1986-02-Mackinlay-TOG-Automating.pdf) Acm Transactions On Graphics (Tog) 5.2 (1986): 110-141.*

# %% [markdown]
# ## Example: Chloropleth maps
#
# <img src='data-science-dataviz/nytimes-2016-primaries-new-hampshire.png' style='height: 500px;'>
#
#
# New-York Times elections 2016 [Iowa](http://www.nytimes.com/elections/2016/primaries/iowa) & [New Hampshire Results Exit Polls](http://www.nytimes.com/elections/2016/primaries/new-hampshire)

# %% [markdown]
# # Visual Mapping
#
# ## *from templates to customization*

# %% [markdown]
# ## Visualization Templates (or Charts)
#
#
# <img src='http://www.excelcharts.com/blog/wp-content/uploads/2013/11/classification-chart-types.png' style='width:100%;'>
#
# Visualization templates can be seen as pre-defined and (usually) well accepted combinations. See The Data Visualisation Catalogue http://www.datavizcatalogue.com/search.html.

# %% [markdown]
# ## Google Visualization
#
# <div style='text-align: center'>
#   <img src='data-science-dataviz/google-visualization.png'>
# </div>
#
# https://developers.google.com/chart/interactive/docs/gallery

# %% [markdown]
# ## Tableau Software: Show Me!
#
# <div style='text-align: center'>
#   <img src='data-science-dataviz/tableau-showme.png' style='height: 500px'>
# </div>
#
#
# Mackinlay J, Hanrahan P, Stolte C. **Show me: automatic presentation for visual analysis.** IEEE Trans Vis Comput Graph. 2007 Nov-Dec;13(6):1137-44.

# %% [markdown]
# ## Tableau Software: Drag & Drop
#
# <div style='text-align: center'>
#   <img src='data-science-dataviz/tableau-mapping.png'>
# </div>
#
# Tableau has a 10-12 year jump on Microsoft here and is a swiss army knife when it comes to data sources. Tableau does monthly updates as well with a big release or 2 every year. Still a much easier product to use and deploy at scale.

# %% [markdown]
# ## Raw by designdensity
#
# <iframe src="https://player.vimeo.com/video/75866661" width="700" height="400" frameborder="0" webkitallowfullscreen mozallowfullscreen allowfullscreen></iframe>
#
# <p><a href="https://vimeo.com/75866661">Raw - Basic Tutorial</a> from <a href="https://vimeo.com/densitydesign">DensityDesign</a> on <a href="https://vimeo.com">Vimeo</a>.</p>

# %% [markdown]
# ## Vega
#
#
# <img src='data-science-dataviz/vega-editor.png' style='width: 800px'>
#
# Vega [charts configuration editor](http://vega.github.io/vega-editor/index.html?mode=vega&spec=bar). You borrow configuration from [existing templates](https://github.com/vega/vega/wiki/Marks). Extend them or override. JSON objects as configurations.

# %% [markdown]
# ## Brunel
#
# <img src='data-science-dataviz/brunel-geomap.png' style='width: 800px'>
#
# http://brunelvis.org/

# %% [markdown]
# # *Preparatory* Visualizations

# %% [markdown]
# ## Trifacta Visual Profiler
#
# https://www.trifacta.com/visual-profiling-for-data-transformation/
#
# <div style='text-align: center'>
#   <img src='https://lh5.googleusercontent.com/Dyia0jy4LTaRhRboLbiHHLdwxXheaO5FFkFtNMp0iC2lpbz7zG9qBHiCzfPi2XKXPtfa6pMmtScb-r8mXlqtGRrx6fltJt1tct_Nnw5Rf908m5453k-j4FCGFkYqoe7f9w' style='height:500px'>
# </div>
#
#
# Trifacta data wrangler, shows most frequent values, outliers or potential variable transformations. http://vis.stanford.edu/papers/wrangler. See also Google Open Refine http://openrefine.org/.

# %% [markdown]
# # *Exploratory* Visualizations

# %% [markdown]
# ## Matlibplot / Seaborn
#
# (From http://stanford.edu/~mwaskom/software/seaborn-dev/tutorial/distributions.html)

# %%
import numpy as np
from numpy.random import randn
import pandas as pd
from scipy import stats
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data = randn(75)
plt.hist(data);

# %%
plt.hist(data, 20, color=sns.desaturate("indianred", .75));

# %%
data1 = stats.poisson(2).rvs(100)
data2 = stats.poisson(5).rvs(100)
max_data = np.r_[data1, data2].max()
bins = np.linspace(0, max_data, max_data + 1)
plt.hist(data1, bins, normed=True, color="#6495ED", alpha=.5)
plt.hist(data2, bins, normed=True, color="#F08080", alpha=.5);

# %%
plt.scatter(data1, data2)

# %%
with sns.axes_style("white"):
    sns.jointplot(data1, data2);

# %%
x = stats.gamma(3).rvs(5000)
plt.hist(x, 70, histtype="stepfilled", alpha=.7);

# %%
y = stats.gamma(3).rvs(5000)
plt.hist(x, 70, histtype="stepfilled", alpha=.7);

# %%
with sns.axes_style("white"):
    sns.jointplot(x, y);

# %%
with sns.axes_style("white"):
    sns.jointplot(x, y, alpha=.1);

# %%
with sns.axes_style("white"):
    sns.jointplot(x, y, kind="hex");

# %%
sns.rugplot(data);

# %%
plt.hist(data, alpha=.3)
sns.rugplot(data);

# %%
sns.distplot(data, kde=False, rug=True);

# %%
sns.set(rc={"figure.figsize": (6, 6)})
data = [data1, data2]
plt.boxplot(data);

# %%
normals = pd.Series(np.random.normal(size=10))
normals.plot()

# %%
variables = pd.DataFrame({'normal': np.random.normal(size=100), 
                       'gamma': np.random.gamma(1, size=100), 
                       'poisson': np.random.poisson(size=100)})
variables.cumsum(0).plot()

# %%
variables.cumsum(0).plot(subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x115272128>,
# ...
#        <matplotlib.axes._subplots.AxesSubplot object at 0x1159cfef0>], dtype=object)

# %% [markdown]
# ## Data Voyager
#
# <!-- <iframe src='http://vega.github.io/voyager/' width='800' height='500'> -->
#
# <img src='data-science-dataviz/idl-data-voyageur.png'>
#
# [Data Voyager](http://vega.github.io/voyager/) automatically generates charts with no input by default (besides loading the dataset). You can interact to get more details and bookmark them.

# %% [markdown]
# ## Scatterplot Matrix
#
#
# <img src='data-science-dataviz/d3-scatterplot-matrix.png' style='height: 600px'>
#
# [D3 Scatterplot Matrix](http://bl.ocks.org/mbostock/raw/4063663/)

# %% [markdown]
# ## Scatterplot Matrix Navigation
#
# <img src='http://romain.vuillemot.net/img/teaser-french-unemployment-data-exploration.png' style='height: 600px'>
#
# INSEE unemployement data exploration using INRIA ScatterDice http://labs.data-publica.com/emploi/. Multidimensional *Grand Tour* visualization.

# %% [markdown]
# <!--<iframe src='https://plot.ly/~jackp/16209/machine-learning-classifier-comparison.embed' width='100%'>-->
#
# ## Machine Learning Classifier Comparison
#
# <img src='data-science-dataviz/plotly-machine-learning.png'>
#
# [Plot.ly](https://plot.ly/~jackp/16209/machine-learning-classifier-comparison.embed)

# %% [markdown]
# # *Monitoring* Visualization

# %% [markdown]
# <iframe src='https://d3fc.io/examples/streaming/index.html' width=900, height=550></iframe>

# %% [markdown]
# <iframe src='http://www.visualsedimentation.org/examples/simple/bubbleChart.html' width=900, height=550></iframe>

# %% [markdown]
# ## Sparklines
#
# <img src='https://camo.githubusercontent.' style='height: 600px'>
#
# https://github.com/swingley/baseball-sparklines. Sparklines [design guidelines](http://www.edwardtufte.com/bboard/q-and-a-fetch-msg?msg_id=0001OR) and [best practices for dashboards](https://www.perceptualedge.com/articles/visual_business_intelligence/best_practices_for_scaling_sparklines.pdf)

# %% [markdown]
# # *Explanatory* Visualizations

# %% [markdown]
# ## D3 & Co.
#
# <img src='data-science-dataviz/d3-homepage.png' style='height: 500px'>
#
#
# [d3](https://d3js.org/). Highchart, NVD3, Rickshaw + their framweork-specific charts (React, ember, ..) and [editor](http://tributary.io/inlet/4653053). See full list on http://keshif.me/demo/VisTools or http://www.jsgraphs.com/.

# %% [markdown]
# ## Four Ways to Slice Obama’s 2013 Budget Proposal
#
# <img src='data-science-dataviz/nytimes-budget-proposal.png' style='width: 700px'>
#
# http://www.nytimes.com/interactive/2012/02/13/us/politics/2013-budget-proposal-graphic.html

# %% [markdown]
# ## Temperature, Humidity and Moisture Content (MC)
#
# <img src='data-science-dataviz/wood-changes.png' style='width: 600px'>
#
# http://woodchanges.com/

# %% [markdown]
# ## How the U.S. and OPEC Drive Oil Prices
#
# <img src='data-science-dataviz/nytimes-oil-prices.png' style='width: 600px'>
#
# http://www.nytimes.com/interactive/2015/09/30/business/how-the-us-and-opec-drive-oil-prices.html?_r=0

# %% [markdown]
# ## A Visual Introduction to Machine Learning
#
# <img src='data-science-dataviz/r2d3-intro-ml.png' style='width: 600px'>
#
# A [Visual Introduction to Machine Learning](http://www.r2d3.us/visual-intro-to-machine-learning-part-1/) by R2D3

# %% [markdown]
# # *What if* Visualizations

# %% [markdown]
# ## 512 Paths to the White House
#
# <img src='data-science-dataviz/nytimes-512-paths.png' style='height: 600px'>
#
# http://www.nytimes.com/interactive/2012/11/02/us/politics/paths-to-the-white-house.html

# %% [markdown]
# ## Champions League Predictions
#
# <img src='data-science-dataviz/predigy-ucl1516.png' style='height: 600px'>
#
# http://predict.re/ucl/

# %% [markdown]
# ## Birth rate models
#
# <img src='data-science-dataviz/flowing-years-probably.png' style='height: 600px'>
#
# http://flowingdata.com/2015/09/23/years-you-have-left-to-live-probably/
#
# Years You Have Left to Live, Probably

# %% [markdown]
# ## What Would It Take To Turn Red/Blue States Red/Blue?
#
# <img src='data-science-dataviz/538-swing-the-election.png' style='height: 600px'>
#
# http://projects.fivethirtyeight.com/2016-swing-the-election/

# %% [markdown]
# ## Climate Change Calculator
#
# <img src='data-science-dataviz/ft-climate-change-calculator.png' style='height: 600px'>
#
# http://ig.ft.com/sites/climate-change-calculator/

# %% [markdown]
# # Wrap-up

# %% [markdown]
# ## *"Show data variations, not design variations"*
#
# <div style='float: right'>Edward Tufte</div>

# %% [markdown]
# ## Design is a Search Problem
#
# <img src='https://d262ilb51hltx0.cloudfront.net/max/1600/1*NYCujc1c1gD9Ta5VrX0D7w.gif'>
#
#
# [Design is a Search Problem](https://youtu.be/fThhbt23SGM?t=32m50s) OpenVis 2014.
# Animated Gif from [The Journalist-Engineer](https://d262ilb51hltx0.cloudfront.net/max/1600/1*NYCujc1c1gD9Ta5VrX0D7w.gif)

# %% [markdown]
# ## Trends
#
# * More advanced interactions combined with fast [server-side rendering](http://bokeh.pydata.org/en/latest/docs/gallery.html)
#
# * More reproductive and collaborative dataviz
#
# * Data journalism and [the U.S. elections](https://www.washingtonpost.com/graphics/politics/2016-election/primaries/new-hampshire-results-analysis/) for the next trends!
#
# * WebGL / Three.js
#
# * Virtual Reality dataviz

# %% [markdown]
# ## Resources
#
# Jobs
# * `<data-vis-jobs@googlegroups.com>`
#
# Social media
# * Twitter [#dataviz](https://twitter.com/search?q=%23dataviz&src=typd)
# * Twitter lists https://twitter.com/infobeautyaward/lists/data-visualisation-people
# * LinkedIn topic https://www.linkedin.com/topic/dataviz
# * Reddit data is beautiful (top 50 sub-reddit), internet is beautiful, some random [discussion thread](https://www.reddit.com/r/dataisbeautiful/comments/435g7b/i_love_live_data_visualizations_heres_every_one/)
#
# Learn more
# * Books: Design for Information, Visualization Analysis and Design.
# * Design processes explained http://animateddata.co.uk/articles/f1-timeline-design/
# * Watch Mike Bostock -
# * Mooc https://twitter.com/YuriEngelhardt/status/697349217027780609
# * Color http://colorbrewer2.org/

# %% [markdown]
# # Merci!
